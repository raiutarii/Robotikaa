# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-01-02 09:41:20--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-02 09:41:20--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   234MB/s    in 0.2s
#
# 2024-01-02 09:41:23 (234 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
#ekstrak dataset
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#melihat direktori dataset
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Bishop', 'Pawn', 'Knight', 'Queen', 'Rook', 'King']

# %%
#menghitung jumlah data pada tiap direktori
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
#melihat salah satu sample dataset
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
) #set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 25s - loss: 1.8253 - accuracy: 0.1784 - val_loss: 1.7869 - val_accuracy: 0.1923 - 25s/epoch - 393ms/step
# Epoch 2/50
# 63/63 - 8s - loss: 1.7894 - accuracy: 0.1924 - val_loss: 1.7820 - val_accuracy: 0.1923 - 8s/epoch - 132ms/step
# Epoch 3/50
# 63/63 - 8s - loss: 1.7806 - accuracy: 0.2044 - val_loss: 1.7650 - val_accuracy: 0.2692 - 8s/epoch - 124ms/step
# Epoch 4/50
# 63/63 - 7s - loss: 1.7438 - accuracy: 0.2204 - val_loss: 1.7751 - val_accuracy: 0.1731 - 7s/epoch - 117ms/step
# Epoch 5/50
# 63/63 - 9s - loss: 1.7328 - accuracy: 0.2725 - val_loss: 1.7308 - val_accuracy: 0.2692 - 9s/epoch - 135ms/step
# Epoch 6/50
# 63/63 - 8s - loss: 1.7016 - accuracy: 0.2705 - val_loss: 1.7703 - val_accuracy: 0.1923 - 8s/epoch - 126ms/step
# Epoch 7/50
# 63/63 - 7s - loss: 1.6477 - accuracy: 0.3126 - val_loss: 1.6596 - val_accuracy: 0.3269 - 7s/epoch - 116ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 1.6217 - accuracy: 0.3427 - val_loss: 1.6323 - val_accuracy: 0.3846 - 9s/epoch - 139ms/step
# Epoch 9/50
# 63/63 - 10s - loss: 1.5160 - accuracy: 0.3888 - val_loss: 1.5190 - val_accuracy: 0.4231 - 10s/epoch - 155ms/step
# Epoch 10/50
# 63/63 - 7s - loss: 1.5125 - accuracy: 0.3667 - val_loss: 1.5030 - val_accuracy: 0.3462 - 7s/epoch - 113ms/step
# Epoch 11/50
# 63/63 - 8s - loss: 1.4530 - accuracy: 0.4188 - val_loss: 1.5791 - val_accuracy: 0.3269 - 8s/epoch - 127ms/step
# Epoch 12/50
# 63/63 - 9s - loss: 1.4282 - accuracy: 0.4329 - val_loss: 1.6706 - val_accuracy: 0.3269 - 9s/epoch - 145ms/step
# Epoch 13/50
# 63/63 - 7s - loss: 1.3658 - accuracy: 0.4489 - val_loss: 1.4897 - val_accuracy: 0.3654 - 7s/epoch - 117ms/step
# Epoch 14/50
# 63/63 - 7s - loss: 1.2811 - accuracy: 0.5130 - val_loss: 1.5196 - val_accuracy: 0.4615 - 7s/epoch - 113ms/step
# Epoch 15/50
# 63/63 - 7s - loss: 1.2706 - accuracy: 0.4950 - val_loss: 1.5202 - val_accuracy: 0.3269 - 7s/epoch - 117ms/step
# Epoch 16/50
# 63/63 - 9s - loss: 1.1903 - accuracy: 0.5291 - val_loss: 1.4956 - val_accuracy: 0.4231 - 9s/epoch - 135ms/step
# Epoch 17/50
# 63/63 - 9s - loss: 1.1838 - accuracy: 0.5531 - val_loss: 1.5004 - val_accuracy: 0.4808 - 9s/epoch - 137ms/step
# Epoch 18/50
# 63/63 - 7s - loss: 1.1201 - accuracy: 0.5571 - val_loss: 1.3570 - val_accuracy: 0.4231 - 7s/epoch - 113ms/step
# Epoch 19/50
# 63/63 - 9s - loss: 1.1520 - accuracy: 0.5671 - val_loss: 1.3450 - val_accuracy: 0.5000 - 9s/epoch - 138ms/step
# Epoch 20/50
# 63/63 - 8s - loss: 1.0527 - accuracy: 0.6012 - val_loss: 1.4699 - val_accuracy: 0.4231 - 8s/epoch - 134ms/step
# Epoch 21/50
# 63/63 - 7s - loss: 0.9945 - accuracy: 0.6453 - val_loss: 1.4216 - val_accuracy: 0.4423 - 7s/epoch - 118ms/step
# Epoch 22/50
# 63/63 - 9s - loss: 0.9410 - accuracy: 0.6393 - val_loss: 1.3692 - val_accuracy: 0.5000 - 9s/epoch - 137ms/step
# Epoch 23/50
# 63/63 - 8s - loss: 0.9793 - accuracy: 0.6433 - val_loss: 1.3727 - val_accuracy: 0.5000 - 8s/epoch - 133ms/step
# Epoch 24/50
# 63/63 - 7s - loss: 0.8682 - accuracy: 0.6814 - val_loss: 1.3384 - val_accuracy: 0.5192 - 7s/epoch - 115ms/step
# Epoch 25/50
# 63/63 - 7s - loss: 0.8371 - accuracy: 0.7034 - val_loss: 1.4207 - val_accuracy: 0.4423 - 7s/epoch - 118ms/step
# Epoch 26/50
# 63/63 - 9s - loss: 0.7478 - accuracy: 0.7214 - val_loss: 1.4324 - val_accuracy: 0.4423 - 9s/epoch - 137ms/step
# Epoch 27/50
# 63/63 - 8s - loss: 0.7984 - accuracy: 0.7134 - val_loss: 1.3979 - val_accuracy: 0.4615 - 8s/epoch - 134ms/step
# Epoch 28/50
# 63/63 - 7s - loss: 0.7623 - accuracy: 0.7174 - val_loss: 1.2659 - val_accuracy: 0.4423 - 7s/epoch - 115ms/step
# Epoch 29/50
# 63/63 - 9s - loss: 0.6655 - accuracy: 0.7535 - val_loss: 1.5838 - val_accuracy: 0.4423 - 9s/epoch - 137ms/step
# Epoch 30/50
# 63/63 - 8s - loss: 0.6473 - accuracy: 0.7675 - val_loss: 1.6981 - val_accuracy: 0.5000 - 8s/epoch - 135ms/step
# Epoch 31/50
# 63/63 - 7s - loss: 0.7026 - accuracy: 0.7255 - val_loss: 1.5120 - val_accuracy: 0.4423 - 7s/epoch - 115ms/step
# Epoch 32/50
# 63/63 - 9s - loss: 0.6671 - accuracy: 0.7655 - val_loss: 1.5225 - val_accuracy: 0.4808 - 9s/epoch - 136ms/step
# Epoch 33/50
# 63/63 - 8s - loss: 0.6123 - accuracy: 0.7595 - val_loss: 1.4452 - val_accuracy: 0.4615 - 8s/epoch - 132ms/step
# Epoch 34/50
# 63/63 - 7s - loss: 0.5672 - accuracy: 0.7956 - val_loss: 1.5913 - val_accuracy: 0.4423 - 7s/epoch - 119ms/step
# Epoch 35/50
# 63/63 - 9s - loss: 0.6044 - accuracy: 0.7936 - val_loss: 1.4134 - val_accuracy: 0.4615 - 9s/epoch - 136ms/step
# Epoch 36/50
# 63/63 - 7s - loss: 0.6204 - accuracy: 0.7896 - val_loss: 1.3494 - val_accuracy: 0.5000 - 7s/epoch - 115ms/step
# Epoch 37/50
# 63/63 - 7s - loss: 0.6172 - accuracy: 0.7655 - val_loss: 1.3918 - val_accuracy: 0.5385 - 7s/epoch - 115ms/step
# Epoch 38/50
# 63/63 - 8s - loss: 0.5689 - accuracy: 0.7856 - val_loss: 1.6954 - val_accuracy: 0.4038 - 8s/epoch - 135ms/step
# Epoch 39/50
# 63/63 - 9s - loss: 0.5503 - accuracy: 0.8076 - val_loss: 1.9757 - val_accuracy: 0.4423 - 9s/epoch - 136ms/step
# Epoch 40/50
# 63/63 - 7s - loss: 0.4829 - accuracy: 0.8216 - val_loss: 1.8195 - val_accuracy: 0.5385 - 7s/epoch - 116ms/step
# Epoch 41/50
# 63/63 - 8s - loss: 0.5404 - accuracy: 0.8136 - val_loss: 1.2509 - val_accuracy: 0.5769 - 8s/epoch - 130ms/step
# Epoch 42/50
# 63/63 - 8s - loss: 0.5221 - accuracy: 0.8056 - val_loss: 1.5648 - val_accuracy: 0.5192 - 8s/epoch - 134ms/step
# Epoch 43/50
# 63/63 - 7s - loss: 0.4899 - accuracy: 0.8277 - val_loss: 1.4119 - val_accuracy: 0.5385 - 7s/epoch - 115ms/step
# Epoch 44/50
# 63/63 - 8s - loss: 0.4566 - accuracy: 0.8337 - val_loss: 1.8192 - val_accuracy: 0.4615 - 8s/epoch - 132ms/step
# Epoch 45/50
# 63/63 - 8s - loss: 0.3937 - accuracy: 0.8457 - val_loss: 1.5075 - val_accuracy: 0.4808 - 8s/epoch - 134ms/step
# Epoch 46/50
# 63/63 - 7s - loss: 0.4633 - accuracy: 0.8477 - val_loss: 1.3568 - val_accuracy: 0.5385 - 7s/epoch - 115ms/step
# Epoch 47/50
# 63/63 - 8s - loss: 0.4553 - accuracy: 0.8377 - val_loss: 1.6151 - val_accuracy: 0.4231 - 8s/epoch - 134ms/step
# Epoch 48/50
# 63/63 - 8s - loss: 0.4769 - accuracy: 0.8096 - val_loss: 1.7440 - val_accuracy: 0.4038 - 8s/epoch - 133ms/step
# Epoch 49/50
# 63/63 - 7s - loss: 0.3207 - accuracy: 0.8737 - val_loss: 1.6097 - val_accuracy: 0.4231 - 7s/epoch - 113ms/step
# Epoch 50/50
# 63/63 - 7s - loss: 0.3443 - accuracy: 0.8737 - val_loss: 1.6264 - val_accuracy: 0.5192 - 7s/epoch - 115ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
